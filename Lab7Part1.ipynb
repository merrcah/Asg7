# %% [markdown]
# <a href="https://colab.research.google.com/github/merrcahoon/Asg7/blob/main/Lab7Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/nn/book")

import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
training_data = list(training_data)

import network2
net=network2.Network([784,100,10])
net.large_weight_initializer()
net.SGD(training_data, 60, 10, 0.1, lmbda=5.0, evaluation_data=validation_data, monitor_evaluation_accuracy=True)
# Out:
# Epoch 0 training complete in  34.53
# Accuracy on evaluation data: 9031 / 10000
# Epoch 1 training complete in  34.61
# Accuracy on evaluation data: 9247 / 10000
# Epoch 2 training complete in  34.47
# Accuracy on evaluation data: 9348 / 10000
# Epoch 3 training complete in  34.70
# Accuracy on evaluation data: 9414 / 10000
# Epoch 4 training complete in  34.56
# Accuracy on evaluation data: 9463 / 10000
# Epoch 5 training complete in  34.44
# Accuracy on evaluation data: 9489 / 10000
# Epoch 6 training complete in  34.35
# Accuracy on evaluation data: 9535 / 10000
# Epoch 7 training complete in  34.41
# Accuracy on evaluation data: 9546 / 10000
# Epoch 8 training complete in  34.44
# Accuracy on evaluation data: 9567 / 10000
# Epoch 9 training complete in  34.66
# Accuracy on evaluation data: 9585 / 10000
# Epoch 10 training complete in  34.39
# Accuracy on evaluation data: 9613 / 10000
# Epoch 11 training complete in  34.46
# Accuracy on evaluation data: 9620 / 10000
# Epoch 12 training complete in  34.35
# Accuracy on evaluation data: 9636 / 10000
# Epoch 13 training complete in  34.36
# Accuracy on evaluation data: 9641 / 10000
# Epoch 14 training complete in  34.31
# Accuracy on evaluation data: 9647 / 10000
# Epoch 15 training complete in  34.45
# Accuracy on evaluation data: 9661 / 10000
# Epoch 16 training complete in  34.24
# Accuracy on evaluation data: 9669 / 10000
# Epoch 17 training complete in  34.43
# Accuracy on evaluation data: 9693 / 10000
# Epoch 18 training complete in  34.44
# Accuracy on evaluation data: 9675 / 10000
# Epoch 19 training complete in  34.53
# Accuracy on evaluation data: 9685 / 10000
# Epoch 20 training complete in  34.28
# Accuracy on evaluation data: 9704 / 10000
# Epoch 21 training complete in  34.31
# Accuracy on evaluation data: 9701 / 10000
# Epoch 22 training complete in  34.27
# Accuracy on evaluation data: 9719 / 10000
# Epoch 23 training complete in  34.32
# Accuracy on evaluation data: 9717 / 10000
# Epoch 24 training complete in  34.17
# Accuracy on evaluation data: 9720 / 10000
# Epoch 25 training complete in  34.08
# Accuracy on evaluation data: 9733 / 10000
# Epoch 26 training complete in  34.18
# Accuracy on evaluation data: 9738 / 10000
# Epoch 27 training complete in  34.20
# Accuracy on evaluation data: 9710 / 10000
# Epoch 28 training complete in  34.07
# Accuracy on evaluation data: 9733 / 10000
# Epoch 29 training complete in  34.14
# Accuracy on evaluation data: 9719 / 10000
# Epoch 30 training complete in  34.14
# Accuracy on evaluation data: 9749 / 10000
# Epoch 31 training complete in  34.20
# Accuracy on evaluation data: 9765 / 10000
# Epoch 32 training complete in  34.29
# Accuracy on evaluation data: 9755 / 10000
# Epoch 33 training complete in  34.38
# Accuracy on evaluation data: 9757 / 10000
# Epoch 34 training complete in  34.24
# Accuracy on evaluation data: 9757 / 10000
# Epoch 35 training complete in  34.33
# Accuracy on evaluation data: 9762 / 10000
# Epoch 36 training complete in  34.22
# Accuracy on evaluation data: 9766 / 10000
# Epoch 37 training complete in  34.21
# Accuracy on evaluation data: 9764 / 10000
# Epoch 38 training complete in  34.34
# Accuracy on evaluation data: 9765 / 10000
# Epoch 39 training complete in  34.27
# Accuracy on evaluation data: 9768 / 10000
# Epoch 40 training complete in  34.44
# Accuracy on evaluation data: 9768 / 10000
# Epoch 41 training complete in  34.42
# Accuracy on evaluation data: 9763 / 10000
# Epoch 42 training complete in  34.37
# Accuracy on evaluation data: 9766 / 10000
# Epoch 43 training complete in  34.33
# Accuracy on evaluation data: 9772 / 10000
# Epoch 44 training complete in  34.24
# Accuracy on evaluation data: 9775 / 10000
# Epoch 45 training complete in  34.39
# Accuracy on evaluation data: 9782 / 10000
# Epoch 46 training complete in  34.43
# Accuracy on evaluation data: 9787 / 10000
# Epoch 47 training complete in  34.46
# Accuracy on evaluation data: 9787 / 10000
# Epoch 48 training complete in  34.30
# Accuracy on evaluation data: 9785 / 10000
# Epoch 49 training complete in  34.37
# Accuracy on evaluation data: 9782 / 10000
# Epoch 50 training complete in  34.24
# Accuracy on evaluation data: 9771 / 10000
# Epoch 51 training complete in  34.32
# Accuracy on evaluation data: 9775 / 10000
# Epoch 52 training complete in  34.31
# Accuracy on evaluation data: 9783 / 10000
# Epoch 53 training complete in  34.35
# Accuracy on evaluation data: 9776 / 10000
# Epoch 54 training complete in  34.37
# Accuracy on evaluation data: 9784 / 10000
# Epoch 55 training complete in  34.17
# Accuracy on evaluation data: 9786 / 10000
# Epoch 56 training complete in  34.17
# Accuracy on evaluation data: 9776 / 10000
# Epoch 57 training complete in  34.17
# Accuracy on evaluation data: 9779 / 10000
# Epoch 58 training complete in  34.30
# Accuracy on evaluation data: 9788 / 10000
# Epoch 59 training complete in  34.12
# Accuracy on evaluation data: 9798 / 10000
# Epoch 59 training complete in  34.12
# ([],
#  [9031,
#   9247,
#   9348,
#   9414,
#   9463,
#   9489,
#   9535,
#   9546,
#   9567,
#   9585,
#   9613,
#   9620,
#   9636,
#   9641,
#   9647,
#   9661,
#   9669,
#   9693,
#   9675,
#   9685,
#   9704,
#   9701,
#   9719,
#   9717,
#   9720,
#   9733,
#   9738,
#   9710,
#   9733,
#   9719,
#   9749,
#   9765,
#   9755,
#   9757,
#   9757,
#   9762,
#   9766,
#   9764,
#   9765,
#   9768,
#   9768,
#   9763,
#   9766,
#   9772,
#   9775,
#   9782,
#   9787,
#   9787,
#   9785,
#   9782,
#   9771,
#   9775,
#   9783,
#   9776,
#   9784,
#   9786,
#   9776,
#   9779,
#   9788,
#   9798],
#  [],
#  [],
#  [34.53397274017334,
#   34.61067247390747,
#   34.465492248535156,
#   34.70008134841919,
#   34.55976629257202,
#   34.43700647354126,
#   34.35028862953186,
#   34.408034563064575,
#   34.438982009887695,
#   34.65646433830261,
#   34.39373564720154,
#   34.4627628326416,
#   34.350176095962524,
#   34.364704847335815,
#   34.306248903274536,
#   34.452643156051636,
#   34.236833333969116,
#   34.42570686340332,
#   34.43784737586975,
#   34.52977800369263,
#   34.27859354019165,
#   34.31238079071045,
#   34.26668334007263,
#   34.32253289222717,
#   34.1687798500061,
#   34.08013606071472,
#   34.18030595779419,
#   34.196937561035156,
#   34.072545528411865,
#   34.1437509059906,
#   34.142157554626465,
#   34.20114254951477,
#   34.29277157783508,
#   34.3806586265564,
#   34.24041676521301,
#   34.33214282989502,
#   34.224464654922485,
#   34.20546913146973,
#   34.34341597557068,
#   34.26860523223877,
#   34.436577558517456,
#   34.41685509681702,
#   34.37445878982544,
#   34.332391023635864,
#   34.24077916145325,
#   34.386298418045044,
#   34.42538595199585,
#   34.456291913986206,
#   34.29511284828186,
#   34.37322497367859,
#   34.237441301345825,
#   34.324981927871704,
#   34.31025314331055,
#   34.35089445114136,
#   34.37411379814148,
#   34.16714382171631,
#   34.17176127433777,
#   34.170196771621704,
#   34.2971887588501,
#   34.123406648635864],
#  2060.039847135544)

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/nn/book")

import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
training_data = list(training_data)

import network2
net=network2.Network([784,100,100,100,10])
net.large_weight_initializer()
net.SGD(training_data, 60, 10, 0.1, lmbda=5.0, evaluation_data=validation_data, monitor_evaluation_accuracy=True)
# Out:
# Epoch 0 training complete in  51.74
# Accuracy on evaluation data: 8901 / 10000
# Epoch 1 training complete in  51.79
# Accuracy on evaluation data: 9193 / 10000
# Epoch 2 training complete in  52.25
# Accuracy on evaluation data: 9320 / 10000
# Epoch 3 training complete in  52.37
# Accuracy on evaluation data: 9436 / 10000
# Epoch 4 training complete in  52.40
# Accuracy on evaluation data: 9475 / 10000
# Epoch 5 training complete in  52.49
# Accuracy on evaluation data: 9497 / 10000
# Epoch 6 training complete in  52.62
# Accuracy on evaluation data: 9538 / 10000
# Epoch 7 training complete in  52.29
# Accuracy on evaluation data: 9542 / 10000
# Epoch 8 training complete in  52.94
# Accuracy on evaluation data: 9583 / 10000
# Epoch 9 training complete in  52.77
# Accuracy on evaluation data: 9595 / 10000
# Epoch 10 training complete in  50.52
# Accuracy on evaluation data: 9626 / 10000
# Epoch 11 training complete in  50.36
# Accuracy on evaluation data: 9609 / 10000
# Epoch 12 training complete in  50.67
# Accuracy on evaluation data: 9642 / 10000
# Epoch 13 training complete in  50.34
# Accuracy on evaluation data: 9643 / 10000
# Epoch 14 training complete in  50.56
# Accuracy on evaluation data: 9671 / 10000
# Epoch 15 training complete in  50.65
# Accuracy on evaluation data: 9666 / 10000
# Epoch 16 training complete in  50.60
# Accuracy on evaluation data: 9638 / 10000
# Epoch 17 training complete in  50.45
# Accuracy on evaluation data: 9662 / 10000
# Epoch 18 training complete in  50.40
# Accuracy on evaluation data: 9679 / 10000
# Epoch 19 training complete in  50.16
# Accuracy on evaluation data: 9675 / 10000
# Epoch 20 training complete in  50.07
# Accuracy on evaluation data: 9675 / 10000
# Epoch 21 training complete in  50.06
# Accuracy on evaluation data: 9697 / 10000
# Epoch 22 training complete in  50.11
# Accuracy on evaluation data: 9692 / 10000
# Epoch 23 training complete in  49.95
# Accuracy on evaluation data: 9684 / 10000
# Epoch 24 training complete in  49.82
# Accuracy on evaluation data: 9697 / 10000
# Epoch 25 training complete in  49.77
# Accuracy on evaluation data: 9720 / 10000
# Epoch 26 training complete in  49.76
# Accuracy on evaluation data: 9721 / 10000
# Epoch 27 training complete in  49.72
# Accuracy on evaluation data: 9734 / 10000
# Epoch 28 training complete in  49.89
# Accuracy on evaluation data: 9722 / 10000
# Epoch 29 training complete in  49.65
# Accuracy on evaluation data: 9650 / 10000
# Epoch 30 training complete in  49.77
# Accuracy on evaluation data: 9731 / 10000
# Epoch 31 training complete in  50.01
# Accuracy on evaluation data: 9726 / 10000
# Epoch 32 training complete in  49.92
# Accuracy on evaluation data: 9727 / 10000
# Epoch 33 training complete in  49.83
# Accuracy on evaluation data: 9755 / 10000
# Epoch 34 training complete in  50.00
# Accuracy on evaluation data: 9751 / 10000
# Epoch 35 training complete in  49.96
# Accuracy on evaluation data: 9758 / 10000
# Epoch 36 training complete in  49.75
# Accuracy on evaluation data: 9738 / 10000
# Epoch 37 training complete in  49.71
# Accuracy on evaluation data: 9745 / 10000
# Epoch 38 training complete in  50.04
# Accuracy on evaluation data: 9756 / 10000
# Epoch 39 training complete in  50.21
# Accuracy on evaluation data: 9772 / 10000
# Epoch 40 training complete in  50.38
# Accuracy on evaluation data: 9742 / 10000
# Epoch 41 training complete in  50.24
# Accuracy on evaluation data: 9748 / 10000
# Epoch 42 training complete in  50.20
# Accuracy on evaluation data: 9773 / 10000
# Epoch 43 training complete in  50.02
# Accuracy on evaluation data: 9741 / 10000
# Epoch 44 training complete in  49.97
# Accuracy on evaluation data: 9782 / 10000
# Epoch 45 training complete in  49.91
# Accuracy on evaluation data: 9745 / 10000
# Epoch 46 training complete in  49.79
# Accuracy on evaluation data: 9774 / 10000
# Epoch 47 training complete in  50.00
# Accuracy on evaluation data: 9743 / 10000
# Epoch 48 training complete in  49.71
# Accuracy on evaluation data: 9762 / 10000
# Epoch 49 training complete in  49.50
# Accuracy on evaluation data: 9730 / 10000
# Epoch 50 training complete in  49.38
# Accuracy on evaluation data: 9788 / 10000
# Epoch 51 training complete in  49.29
# Accuracy on evaluation data: 9791 / 10000
# Epoch 52 training complete in  49.23
# Accuracy on evaluation data: 9727 / 10000
# Epoch 53 training complete in  49.35
# Accuracy on evaluation data: 9785 / 10000
# Epoch 54 training complete in  49.28
# Accuracy on evaluation data: 9737 / 10000
# Epoch 55 training complete in  49.32
# Accuracy on evaluation data: 9790 / 10000
# Epoch 56 training complete in  49.51
# Accuracy on evaluation data: 9786 / 10000
# Epoch 57 training complete in  49.87
# Accuracy on evaluation data: 9779 / 10000
# Epoch 58 training complete in  49.94
# Accuracy on evaluation data: 9787 / 10000
# Epoch 59 training complete in  49.89
# Accuracy on evaluation data: 9730 / 10000
# Epoch 59 training complete in  49.89
# ([],
#  [8901,
#   9193,
#   9320,
#   9436,
#   9475,
#   9497,
#   9538,
#   9542,
#   9583,
#   9595,
#   9626,
#   9609,
#   9642,
#   9643,
#   9671,
#   9666,
#   9638,
#   9662,
#   9679,
#   9675,
#   9675,
#   9697,
#   9692,
#   9684,
#   9697,
#   9720,
#   9721,
#   9734,
#   9722,
#   9650,
#   9731,
#   9726,
#   9727,
#   9755,
#   9751,
#   9758,
#   9738,
#   9745,
#   9756,
#   9772,
#   9742,
#   9748,
#   9773,
#   9741,
#   9782,
#   9745,
#   9774,
#   9743,
#   9762,
#   9730,
#   9788,
#   9791,
#   9727,
#   9785,
#   9737,
#   9790,
#   9786,
#   9779,
#   9787,
#   9730],
#  [],
#  [],
#  [51.74074363708496,
#   51.786489486694336,
#   52.24932599067688,
#   52.37062978744507,
#   52.39796686172485,
#   52.489171504974365,
#   52.619964361190796,
#   52.286170959472656,
#   52.9441442489624,
#   52.772540807724,
#   50.52265167236328,
#   50.36488604545593,
#   50.66710877418518,
#   50.33691883087158,
#   50.562299728393555,
#   50.65309548377991,
#   50.60399675369263,
#   50.453195095062256,
#   50.403714418411255,
#   50.16235160827637,
#   50.07242155075073,
#   50.06498336791992,
#   50.11278510093689,
#   49.9460711479187,
#   49.82087564468384,
#   49.77208423614502,
#   49.75856685638428,
#   49.72171354293823,
#   49.89068078994751,
#   49.65305256843567,
#   49.7736554145813,
#   50.00605630874634,
#   49.919326066970825,
#   49.83442759513855,
#   50.00105333328247,
#   49.96324586868286,
#   49.7504608631134,
#   49.71158313751221,
#   50.04302430152893,
#   50.21272945404053,
#   50.37767815589905,
#   50.236018896102905,
#   50.199031591415405,
#   50.015963554382324,
#   49.9720253944397,
#   49.906534910202026,
#   49.78831076622009,
#   49.99982452392578,
#   49.70682907104492,
#   49.49520301818848,
#   49.37995386123657,
#   49.28819704055786,
#   49.229825258255005,
#   49.34776735305786,
#   49.27612638473511,
#   49.32027792930603,
#   49.50738596916199,
#   49.87097954750061,
#   49.937090158462524,
#   49.89249777793884],
#  3021.1636843681335)
